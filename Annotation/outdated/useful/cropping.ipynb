# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img_filepath = '/Users/jenny.vo-phamhi/Documents/FISH-annotation/Annotation/smFISH_test/C2-ISP_293T_TFRC_InSituPrep_20180712_1_MMStack_Pos0_300.png'

img = mpimg.imread(img_filepath)
print(img)
fig = plt.figure(figsize=(14,12))
plt.imshow(img, cmap='gray')
plt.show()

crop = img[250:300, 100:150]
print(crop)
fig = plt.figure()
plt.imshow(crop, cmap='gray')
plt.show()
# Out:
# [[0.04313726 0.04313726 0.03137255 ... 0.03921569 0.03529412 0.03921569]
#  [0.03921569 0.04313726 0.03921569 ... 0.03921569 0.03921569 0.04313726]
#  [0.04313726 0.03921569 0.03529412 ... 0.03921569 0.03529412 0.04313726]
#  ...
#  [0.04313726 0.03921569 0.03529412 ... 0.03921569 0.04313726 0.04313726]
#  [0.03529412 0.03137255 0.02745098 ... 0.03921569 0.03921569 0.04313726]
#  [0.04705882 0.03137255 0.02745098 ... 0.03921569 0.03921569 0.03921569]]
# [[0.10196079 0.14509805 0.26666668 ... 0.06666667 0.06666667 0.09019608]
#  [0.12156863 0.12156863 0.13333334 ... 0.06666667 0.05882353 0.07058824]
#  [0.13333334 0.12156863 0.12156863 ... 0.06666667 0.05882353 0.07058824]
#  ...
#  [0.05098039 0.04705882 0.04705882 ... 0.09019608 0.04705882 0.04705882]
#  [0.04705882 0.05098039 0.04705882 ... 0.22352941 0.08235294 0.05098039]
#  [0.03529412 0.04313726 0.04313726 ... 0.32941177 0.12941177 0.05098039]]
