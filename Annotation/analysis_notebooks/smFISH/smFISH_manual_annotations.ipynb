# %%
import math
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
import

csv_filepath = '/Users/jenny.vo-phamhi/Documents/FISH-annotation/Annotation/smFISH_test/700.csv'
img_filepath = '/Users/jenny.vo-phamhi/Documents/FISH-annotation/Annotation/smFISH_test/C2-ISP_293T_TFRC_InSituPrep_20180712_1_MMStack_Pos0_700.png'

fig = plt.figure(figsize = (16,14))
ref_df = pd.read_csv(csv_filepath)
ref_points = ref_df.loc[:,['col', 'row']].as_matrix()
x_coords = ref_points[:,0]
y_coords = ref_points[:,1]
x_coords_shifted = [x_coord-2 for x_coord in x_coords]
y_coords_shifted = [y_coord-2 for y_coord in y_coords]
plt.scatter(x_coords_shifted, y_coords_shifted, s=4, c='y')
plt.imshow(mpimg.imread(img_filepath),cmap='gray')
plt.show()
print('num spots = ' + str(len(x_coords)))
# Out:
# num spots = 268
